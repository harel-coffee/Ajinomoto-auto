# %% [markdown]
# # Art Example

# %%
import pandas as pd
from IPython.display import display

# %%
def load_data(file,features,target):
    df = pd.read_csv(file)
    
    #pivot table
    #df = pivot_table(df)
    
    #features, target
    return df[features].values,df[target].values

def load_edd_data(slug,features,target)

X,y = load_data('../data/PCAPexample.csv')
# Out:
#      Study ID    Study Name  Study Contact  Line ID Line Name Control  Strain  \
# 0       38572  PCAP example            NaN    38595      B-Mm       F     NaN
# 1       38572  PCAP example            NaN    38621      A-Ml       F     NaN
# 2       38572  PCAP example            NaN    38577     BL-Mm       F     NaN
# 3       38572  PCAP example            NaN    38585      A-Mh       F     NaN
# 4       38572  PCAP example            NaN    38589      A-Hl       F     NaN
# 5       38572  PCAP example            NaN    38591     2X-Hh       F     NaN
# 6       38572  PCAP example            NaN    38599      B-Mh       F     NaN
# 7       38572  PCAP example            NaN    38603      B-Hl       F     NaN
# 8       38572  PCAP example            NaN    38607      B-Hm       F     NaN
# 9       38572  PCAP example            NaN    38611      B-Hh       F     NaN
# 10      38572  PCAP example            NaN    38615      A-Hm       F     NaN
# ...
